# %% [markdown]
# # Prepare Vietnamese Tax Legal Artifact\n
# \n
# Notebook nay chi la remote runner. Logic preprocessing that su nam trong repo: `scripts/prepare_artifact.py` va `app/ingestion/*`.

# %%
# !git clone https://github.com/YOUR_USERNAME/AGENTIC-RAG.git\n
# %cd AGENTIC-RAG\n
# !pip install -r requirements.txt

# %%
# !python scripts/prepare_artifact.py --max-documents 200 --output-dir artifacts/legal_tax_v1_200

# %%
# !cat artifacts/legal_tax_v1_200/stats.json
# !zip -r legal_tax_v1_200.zip artifacts/legal_tax_v1_200

# %% [markdown]
# Tai file `legal_tax_v1_200.zip` ve local, giai nen vao thu muc `artifacts/`, roi chay:\n
# \n
# ```powershell\n
# python scripts/06_import_artifact.py --artifact-dir artifacts/legal_tax_v1_200 --reset\n
# ```
